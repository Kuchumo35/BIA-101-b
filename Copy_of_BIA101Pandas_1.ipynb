# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuchumo35/BIA-101-b/blob/main/Copy_of_BIA101Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# BIA 101
print('hello')
print('hello')
print('hello')
print('hello')
# Out:
# hello
# hello
# hello
# hello

# %%
import pandas as pd

# %%
data = {
    'Yes': [50,21],
    'No' : [131,2]
}

menu = {
    'momo' : 30,
    'tea' : 20,
    'rice' : 50,
    'curry' : 40

}

print(data['Yes'])
print(menu['curry'])
print(menu['momo'])

pd.DataFrame(data)
# Out:
# [50, 21]
# 40
# 30
#    Yes   No
# 0   50  131
# 1   21    2

# %%
user_comments = {
    'Luffy' : ['Hey, Zoro','Come here'],
    'Zoro' : ['Yes, Captain', 'Coming!'],

}

row_indexes = ['Conversation A', 'Conversation B']

pd.DataFrame(user_comments, index = row_indexes)
# Out:
#                     Luffy          Zoro
# Conversation A  Hey, Zoro  Yes, Captain
# Conversation B  Come here       Coming!

# %%
pd.read_csv('file.csv')
# Out:
#    Product A  Product B  Product C  Unnamed: 3
# 0         30         21          9         NaN
# 1         35         34          1         NaN
# 2         41         11         11         NaN

# %%
df = pd.read_csv('file.csv')

# %%
df
# Out:
#    Product A  Product B  Product C  Unnamed: 3
# 0         30         21          9         NaN
# 1         35         34          1         NaN
# 2         41         11         11         NaN

# %%
df.shape
# Out:
# (3, 4)

# %%
pd.read_csv('./sample_data/california_housing_train.csv')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
Path = './sample_data/california_housing_train.csv'

# %%
housing_df = pd.read_csv(Path)

# %%
housing_df.shape
# Out:
# (17000, 9)

# %%
housing_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
housing_df.total_rooms
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64

# %%
housing_df.total_rooms[10000]
# Out:
# 1960.0

# %%
housing_df.total_rooms[9999]
# Out:
# 1081.0

# %%
housing_df.iloc[100:150, 1]
# Out:
# 100    32.79
# 101    32.69
# 102    33.20
# 103    32.87
# 104    33.04
# 105    33.04
# 106    32.80
# 107    32.79
# 108    32.75
# 109    33.36
# 110    33.35
# 111    33.09
# 112    32.80
# 113    33.26
# 114    33.49
# 115    34.20
# 116    32.93
# 117    33.34
# 118    33.36
# 119    35.55
# 120    33.38
# 121    33.28
# 122    33.30
# 123    33.32
# 124    33.40
# 125    33.19
# 126    32.74
# 127    33.51
# 128    33.41
# 129    34.18
# 130    34.12
# 131    33.33
# 132    34.20
# 133    34.15
# 134    33.86
# 135    34.15
# 136    33.64
# 137    33.53
# 138    34.22
# 139    34.14
# 140    33.69
# 141    33.64
# 142    33.68
# 143    33.67
# 144    33.66
# 145    33.53
# 146    33.69
# 147    33.67
# 148    33.67
# 149    33.70
# Name: latitude, dtype: float64

# %%
housing_df.housing_median_age.describe()
# Out:
# count    17000.000000
# mean        28.589353
# std         12.586937
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: housing_median_age, dtype: float64
